# %%
# %cd /content/drive/My Drive/yolo
# Out:
# /content/drive/My Drive/yolo

# %%
# %pwd
# Out:
# '/content/drive/My Drive/yolo'

# %%
# !python train.py
# Out:
# Namespace(batch_size=16, checkpoint_dir='checkpoints', checkpoint_interval=1, class_path='/content/drive/My Drive/yolo/config/coco.names', conf_thres=0.8, data_config_path='/content/drive/My Drive/yolo/config/coco.data', epochs=5, image_folder='/content/drive/My Drive/yolo/data/images', img_size=416, model_config_path='/content/drive/My Drive/yolo/config/yolov3.cfg', n_cpu=0, nms_thres=0.4, use_cuda=True, weights_path='/content/drive/My Drive/yolo/config/yolov3.weights')
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# ...
